# %%
import random

from brian2 import defaultclock, run, network_operation, randn
from brian2 import ms, mV, nS, nF, Hz, kHz, nA, second
from brian2 import NeuronGroup, PoissonGroup, Synapses, Network
from brian2 import StateMonitor, SpikeMonitor, PopulationRateMonitor

from brian2tools import plot_raster, plot_rate


import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import lfilter

# %% [markdown]
# # Computational Neuroscience Models that use `Brian2`
#
# ## Resources
#
# 1. Link to [database of models](https://senselab.med.yale.edu/ModelDB/ModelList?id=231240&allsimu=true).
# 2. A [Jupyter notebook](https://github.com/juletx/spiking-neural-network/blob/main/notebooks/P44_Izhikevich_SNN_Model_NN_D2.ipynb) that creates all the different types of Izhekevich neurons

# %%
def simulation(Ne=800, Ni=200, tau=1, duration=1000):
    
    # Parameters:
        # Ne: excitatory neurons quantity.
        # Ni: inhibitory neurons quantity.
        # tau: dv/dt and du/dt equations correspond to the change in a concrete time interval 
        #      that variables v and u suffer. This concrete time interval is defined by the value tau.
        # duration: defines the duration of the simulation.
    
    defaultclock.dt = 0.1*ms
    tau = tau/ms
    duration = duration*ms
    
    # Two behaviour differential equations:
    #    1) dv/dt: represents the membrane potential evolution during time.
    #    2) du/dt: represents the membrane recovery variable evolution during time.
    
    # Independent variables:
    #    1) I: represents the input current.
    #    2) v: represents the membrane potential of the neuron.
    #    3) u: represents a membrane recovery variable which provides negative feedback to v. This feedback
    #          is caused due to activation of K+ ionic currents and inactivation of Na+ ionic currents.
    #    4) a: describes the time scale of the recovery variable u.
    #    5) b: describes the sensitivity of the recovery variable u to the subthreshold fluctuations
    #          of the membrane potential v.
    #    6) c: describes the after-spike reset value of the membrane potential v.
    #    7) d: describes after-spike reset of the recovery variable u.
    
    eqs = '''
    dv/dt = tau*(0.04*v**2+5*v+140-u+I) : 1
    du/dt = tau*a*(b*v-u) : 1
    I : 1
    a : 1
    b : 1
    c : 1
    d : 1
    '''
    
    # Excitatory neurons group network. Quantity of Ne (800)
    Ge = NeuronGroup(Ne, eqs, threshold='v>=30', reset='v=c; u+=d', method='euler')
    # Inhibitory neurons group network. Quantity of Ni (200)
    Gi = NeuronGroup(Ni, eqs, threshold='v>=30', reset='v=c; u+=d', method='euler')
    
    # Initial values of excitatory neurons parameters a, b, c, d, v and u 
    Ge.a = 0.02
    Ge.b = 0.2
    Ge.c = '-65+15*rand()**2'
    Ge.d = '8-6*rand()**2'
    Ge.v = -65
    Ge.u = Ge.b*-65
    # Initial values of inhibitory neurons parameters a, b, c, d, v and u 
    Gi.a = '0.02+0.08*rand()'
    Gi.b = '0.25-0.05*rand()'
    Gi.c = -65
    Gi.d = 2
    Gi.v = -65
    Gi.u = Gi.b*-65
    
    # Creating synaptical connections between neurons. 4 types of connections:
    #    1) See: a group of excitatory neurons where connections are given by excitatory-excitatory relations
    #    2) Sei: a group of excitatory and inhibitory neurons where connections are given by 
    #             excitatory->inhibitory relations.
    #    3) Sie: a group of excitatory and inhibitory neurons where connections are given by 
    #             inhibitory->excitatory relations.
    #    4) Sii: a group of inhibitory neurons where connections are given by inhibitory-inhibitory relations.
    
    See = Synapses(Ge, Ge, 'w : 1', on_pre='I_post += w')
    See.connect()
    See.w = '0.5*rand()'
    
    Sei = Synapses(Ge, Gi, 'w : 1', on_pre='I_post += w')
    Sei.connect()
    Sei.w = '0.5*rand()'
    
    Sie = Synapses(Gi, Ge, 'w : 1', on_pre='I_post += w')
    Sie.connect()
    Sie.w = '-rand()'
    
    Sii = Synapses(Gi, Gi, 'w : 1', on_pre='I_post += w')
    Sii.connect()
    Sii.w = '-rand()'
    
    # Creating a monitor to measure the values of the first neuron
    Me = StateMonitor(Ge, ('v', 'u', 'I'), record=0)
   
    # Creating monitors that records each NeuronGroup spikes times
    Se = SpikeMonitor(Ge)
    Si = SpikeMonitor(Gi)
    
    # Compute I randomly with normal distribution in each time step
    Ge.run_regularly('I = 5*randn()', dt=tau*ms**2)
    Gi.run_regularly('I = 2*randn()', dt=tau*ms**2)

    # Run the model for a time defined by duration variable
    run(duration)
   
    # Plotting
    plt.figure(figsize=(20, 20))
    # Plot numbers of spiking neurons
    plt.subplot(2,1,1)
    plt.plot(Se.t/ms, Se.i, '.k', ms=3, c='C0', label='Excitatory')
    plt.plot(Si.t/ms, Si.i+Ne, '.k', ms=3, c='C1', label='Inhibitory')
    plt.axhline(Ne, ls='-', c='C2', lw=2, label='Ne')
    plt.xlim(0, duration/ms)
    plt.ylim(0, Ne+Ni)
    plt.xlabel('Time (ms)')
    plt.ylabel('Neuron number')
    plt.title('Numbers of the spiking neurons')
    plt.legend()
    # Plot spikes of first neuron
    plt.subplot(2,1,2)
    plt.plot(Me.t/ms, Me.v[0], label='v')
    plt.plot(Me.t/ms, Me.u[0], label='u')
    plt.plot(Me.t/ms, Me.I[0], label='I')
    plt.axhline(30, ls='-', c='C3', lw=2, label='v=30')
    plt.xlim(0, duration/ms)
    plt.xlabel('Time (ms)')
    plt.ylabel('v, u, I')
    plt.title('v, u and I values of the first neuron')
    plt.legend()

# %%
simulation()
# Out:
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_ln3g9x40/var
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_ln3g9x40/var/folders
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_ln3g9x40/var/folders/s1
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_ln3g9x40/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_ln3g9x40/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_ln3g9x40/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_ln3g9x40
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -c /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_ln3g9x40/flag_test.cpp -o /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_ln3g9x40/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_ln3g9x40/flag_test.o -w
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mzqly165/var
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mzqly165/var/folders
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mzqly165/var/folders/s1
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mzqly165/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mzqly165/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mzqly165/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mzqly165
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -c /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mzqly165/flag_test.cpp -o /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mzqly165/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mzqly165/flag_test.o -O3
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_387uz905/var
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_387uz905/var/folders
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_387uz905/var/folders/s1
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_387uz905/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_387uz905/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_387uz905/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_387uz905
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -c /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_387uz905/flag_test.cpp -o /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_387uz905/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_387uz905/flag_test.o -ffast-math
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_nzjt2ncq/var
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_nzjt2ncq/var/folders
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_nzjt2ncq/var/folders/s1
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_nzjt2ncq/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_nzjt2ncq/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_nzjt2ncq/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_nzjt2ncq
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -c /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_nzjt2ncq/flag_test.cpp -o /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_nzjt2ncq/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_nzjt2ncq/flag_test.o -fno-finite-math-only
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_6lalimem/var
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_6lalimem/var/folders
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_6lalimem/var/folders/s1
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_6lalimem/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_6lalimem/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_6lalimem/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_6lalimem
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -c /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_6lalimem/flag_test.cpp -o /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_6lalimem/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_6lalimem/flag_test.o -march=native
# WARNING    Removing unsupported flag '-march=native' from compiler flags. [brian2.codegen.cpp_prefs]
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mg_2cws4/var
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mg_2cws4/var/folders
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mg_2cws4/var/folders/s1
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mg_2cws4/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mg_2cws4/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T
# INFO:root:creating /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mg_2cws4/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mg_2cws4
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -c /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mg_2cws4/flag_test.cpp -o /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mg_2cws4/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/brian_flag_test_mg_2cws4/flag_test.o -std=c++11
# INFO:root:building '_cython_magic_756abdb94951be5a0c9a87c3de45b44c' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_756abdb94951be5a0c9a87c3de45b44c.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_756abdb94951be5a0c9a87c3de45b44c.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_756abdb94951be5a0c9a87c3de45b44c.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_756abdb94951be5a0c9a87c3de45b44c.cpython-39-darwin.so
# INFO:root:building '_cython_magic_04e78984467fc848062b941d26da04fb' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_04e78984467fc848062b941d26da04fb.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_04e78984467fc848062b941d26da04fb.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_04e78984467fc848062b941d26da04fb.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_04e78984467fc848062b941d26da04fb.cpython-39-darwin.so
# INFO:root:building '_cython_magic_114d05358d36904cdbf3b73026bec177' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_114d05358d36904cdbf3b73026bec177.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_114d05358d36904cdbf3b73026bec177.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_114d05358d36904cdbf3b73026bec177.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_114d05358d36904cdbf3b73026bec177.cpython-39-darwin.so
# INFO:root:building '_cython_magic_b2c5e1440b26e0f93e8fdd14f784e4be' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_b2c5e1440b26e0f93e8fdd14f784e4be.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_b2c5e1440b26e0f93e8fdd14f784e4be.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_b2c5e1440b26e0f93e8fdd14f784e4be.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_b2c5e1440b26e0f93e8fdd14f784e4be.cpython-39-darwin.so
# INFO:root:building '_cython_magic_777015b87be9caa6b11b1248ea63a7f9' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_777015b87be9caa6b11b1248ea63a7f9.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_777015b87be9caa6b11b1248ea63a7f9.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_777015b87be9caa6b11b1248ea63a7f9.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_777015b87be9caa6b11b1248ea63a7f9.cpython-39-darwin.so
# INFO:root:building '_cython_magic_959579fd601a3c5bd45c11c676f9b2e8' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_959579fd601a3c5bd45c11c676f9b2e8.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_959579fd601a3c5bd45c11c676f9b2e8.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_959579fd601a3c5bd45c11c676f9b2e8.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_959579fd601a3c5bd45c11c676f9b2e8.cpython-39-darwin.so
# INFO:root:building '_cython_magic_f37b1c8f0d4fca2ff554a874e304eb87' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f37b1c8f0d4fca2ff554a874e304eb87.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f37b1c8f0d4fca2ff554a874e304eb87.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f37b1c8f0d4fca2ff554a874e304eb87.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f37b1c8f0d4fca2ff554a874e304eb87.cpython-39-darwin.so
# INFO:root:building '_cython_magic_ca7323a9180f0cb5e680850e9057a4a0' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ca7323a9180f0cb5e680850e9057a4a0.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ca7323a9180f0cb5e680850e9057a4a0.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ca7323a9180f0cb5e680850e9057a4a0.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ca7323a9180f0cb5e680850e9057a4a0.cpython-39-darwin.so
# INFO:root:building '_cython_magic_e630849090a13afea26d0f19e59313c4' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_e630849090a13afea26d0f19e59313c4.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_e630849090a13afea26d0f19e59313c4.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_e630849090a13afea26d0f19e59313c4.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_e630849090a13afea26d0f19e59313c4.cpython-39-darwin.so
# INFO:root:building '_cython_magic_205e45572730e9187779c534306f9417' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_205e45572730e9187779c534306f9417.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_205e45572730e9187779c534306f9417.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_205e45572730e9187779c534306f9417.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_205e45572730e9187779c534306f9417.cpython-39-darwin.so
# INFO:root:building '_cython_magic_d33eda6c5c33716426215a3d65c43104' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_d33eda6c5c33716426215a3d65c43104.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_d33eda6c5c33716426215a3d65c43104.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_d33eda6c5c33716426215a3d65c43104.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_d33eda6c5c33716426215a3d65c43104.cpython-39-darwin.so
# INFO:root:building '_cython_magic_454964162dda9b9eefc39d61261e8e6c' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_454964162dda9b9eefc39d61261e8e6c.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_454964162dda9b9eefc39d61261e8e6c.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_454964162dda9b9eefc39d61261e8e6c.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_454964162dda9b9eefc39d61261e8e6c.cpython-39-darwin.so
# INFO:root:building '_cython_magic_dfda2da1331a6cb43117412d44b4d925' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_dfda2da1331a6cb43117412d44b4d925.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_dfda2da1331a6cb43117412d44b4d925.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_dfda2da1331a6cb43117412d44b4d925.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_dfda2da1331a6cb43117412d44b4d925.cpython-39-darwin.so
# INFO:root:building '_cython_magic_84494eef378e29e29bdef5181e3ad597' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_84494eef378e29e29bdef5181e3ad597.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_84494eef378e29e29bdef5181e3ad597.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_84494eef378e29e29bdef5181e3ad597.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_84494eef378e29e29bdef5181e3ad597.cpython-39-darwin.so
# INFO:root:building '_cython_magic_4772d2e6e17333aca7ce556f2afda072' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_4772d2e6e17333aca7ce556f2afda072.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_4772d2e6e17333aca7ce556f2afda072.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_4772d2e6e17333aca7ce556f2afda072.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_4772d2e6e17333aca7ce556f2afda072.cpython-39-darwin.so
# INFO:root:building '_cython_magic_a482bf284cfd13b8a37c17509efc9690' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_a482bf284cfd13b8a37c17509efc9690.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_a482bf284cfd13b8a37c17509efc9690.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_a482bf284cfd13b8a37c17509efc9690.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_a482bf284cfd13b8a37c17509efc9690.cpython-39-darwin.so
# INFO:root:building '_cython_magic_5fa609d7f48a739959493c379cc6347b' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5fa609d7f48a739959493c379cc6347b.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5fa609d7f48a739959493c379cc6347b.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5fa609d7f48a739959493c379cc6347b.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5fa609d7f48a739959493c379cc6347b.cpython-39-darwin.so
# INFO:root:building '_cython_magic_0c83d42e6d7c920ebf521c2665a54c21' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_0c83d42e6d7c920ebf521c2665a54c21.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_0c83d42e6d7c920ebf521c2665a54c21.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_0c83d42e6d7c920ebf521c2665a54c21.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_0c83d42e6d7c920ebf521c2665a54c21.cpython-39-darwin.so
# INFO:root:building '_cython_magic_ef5ebc93a3989c75c304c33af22e5a7f' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ef5ebc93a3989c75c304c33af22e5a7f.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ef5ebc93a3989c75c304c33af22e5a7f.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ef5ebc93a3989c75c304c33af22e5a7f.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ef5ebc93a3989c75c304c33af22e5a7f.cpython-39-darwin.so
# INFO:root:building '_cython_magic_c6bffd1a408061f13cb627e64da01153' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_c6bffd1a408061f13cb627e64da01153.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_c6bffd1a408061f13cb627e64da01153.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_c6bffd1a408061f13cb627e64da01153.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_c6bffd1a408061f13cb627e64da01153.cpython-39-darwin.so
# INFO:root:building '_cython_magic_8200d0eee18000323f36cc2f5b7921c5' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8200d0eee18000323f36cc2f5b7921c5.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8200d0eee18000323f36cc2f5b7921c5.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8200d0eee18000323f36cc2f5b7921c5.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8200d0eee18000323f36cc2f5b7921c5.cpython-39-darwin.so
# INFO:root:building '_cython_magic_20e986a72f6f79c87b451b5073897c05' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_20e986a72f6f79c87b451b5073897c05.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_20e986a72f6f79c87b451b5073897c05.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_20e986a72f6f79c87b451b5073897c05.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_20e986a72f6f79c87b451b5073897c05.cpython-39-darwin.so
# INFO:root:building '_cython_magic_6ac78a675b54e51d4b595faeef83650f' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_6ac78a675b54e51d4b595faeef83650f.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_6ac78a675b54e51d4b595faeef83650f.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_6ac78a675b54e51d4b595faeef83650f.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_6ac78a675b54e51d4b595faeef83650f.cpython-39-darwin.so
# INFO:root:building '_cython_magic_c5e1c9c08a2348dd776f837e96b62fa4' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_c5e1c9c08a2348dd776f837e96b62fa4.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_c5e1c9c08a2348dd776f837e96b62fa4.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_c5e1c9c08a2348dd776f837e96b62fa4.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_c5e1c9c08a2348dd776f837e96b62fa4.cpython-39-darwin.so
# INFO:root:building '_cython_magic_b0058551306f43631ab67255ee749d31' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_b0058551306f43631ab67255ee749d31.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_b0058551306f43631ab67255ee749d31.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_b0058551306f43631ab67255ee749d31.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_b0058551306f43631ab67255ee749d31.cpython-39-darwin.so
# INFO:root:building '_cython_magic_bcae7eadd7d8b294489870f641449e4d' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_bcae7eadd7d8b294489870f641449e4d.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_bcae7eadd7d8b294489870f641449e4d.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_bcae7eadd7d8b294489870f641449e4d.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_bcae7eadd7d8b294489870f641449e4d.cpython-39-darwin.so
# WARNING    /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/ipykernel_40271/4235168853.py:101: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ".k" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(Se.t/ms, Se.i, '.k', ms=3, c='C0', label='Excitatory')
#  [py.warnings]
# WARNING:py.warnings:/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/ipykernel_40271/4235168853.py:101: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ".k" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(Se.t/ms, Se.i, '.k', ms=3, c='C0', label='Excitatory')
#
# WARNING    /var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/ipykernel_40271/4235168853.py:102: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ".k" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(Si.t/ms, Si.i+Ne, '.k', ms=3, c='C1', label='Inhibitory')
#  [py.warnings]
# WARNING:py.warnings:/var/folders/s1/lzq1k08d2572hqgdq0r3j1qm0000gn/T/ipykernel_40271/4235168853.py:102: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string ".k" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(Si.t/ms, Si.i+Ne, '.k', ms=3, c='C1', label='Inhibitory')

# %% [markdown]
# ## Klaus Wimmer 2015 Model
# ([source](https://github.com/l-luo1/Brian2-Wimmer-Model-Translation))

# %%
#It begins! 
def make_sensory_circuit(): 
     # Populations 
    N_E = 1600                                   # Total number of excitatory neurons
    N_E1 = int(0.5 * N_E)                        # Size of excitatory population E1
    N_E2 = N_E1                                  # Size of excitatory population E2
    N_I = 400                                    # Size of inhibitory population I
    N_X = 1000                                   # Size of external population X
    N_X1 = int(0.5 * N_X)                        # Size of external population X1
    N_X2 = int(0.5 * N_X)                        # Size of external population X2

        # Connectivity - local recurrent connections
    p = 0.2                                      # Connection probability for (EE, EI, IE, II)
    w_p = 1.3                                    # Relative synaptic strength of connections within populations E1 and E2
    w_m = 2.0 - w_p                              # Relative synaptic strength of connections across populations E1 and E2
    gEE = 0.7589 * nS  #Brian2 loves units!                           # Weight of excitatory to excitatory synapses
    gEI = 1.5179 * nS                            # Weight of excitatory to inhibitory synapses
    gIE = 12.6491 * nS                           # Weight of inhibitory to excitatory synapses
    gII = gIE                                    # Weight of inhibitory to inhibitory synapses
    dE = (0.5 * ms, 1.5 * ms)                    # Range of uniformly distributed transmission delays of excitatory connections
    dI = (0.1 * ms, 0.9 * ms)                    # Range of uniformly distributed transmission delays of inhibitory connections

        # Connectivity - external connections
    p_x = 0.32                                   # Connection probability for external connections
    alpha_x = 0.0
    gextE = 1.7076 * nS                          # Weight of external to excitatory synapses
    gextI = 1.7076 * nS                          # Weight of external to inhibitory synapses
    dXE = (0.5 * ms, 1.5 * ms)                   # Range of uniformly distributed transmission delays of external connections

        # Neuron model
    CmE = 0.25 * nF                              # Membrane capacitance of excitatory neurons
    CmI = 0.25 * nF                              # Membrane capacitance of inhibitory neurons
    gLeakE = 16.7 * nS                           # Leak conductance of excitatory neurons
    gLeakI = 16.7 * nS                           # Leak conductance of inhibitory neurons
    Vl = -70.0 * mV                              # Resting potential
    Vt = -50.0 * mV                              # Spiking threshold
    Vr = -60.0 * mV                              # Reset potential
    tau_refE = 2.0 * ms                          # Absolute refractory period of excitatory neurons
    tau_refI = 1.0 * ms                          # Absolute refractory period of inhibitory neurons
    nu_ext = 12.5 * Hz                           # Firing rate of external Poisson neurons 

        # Synapse model
    VrevE = 0 * mV                               # Reversal potential of excitatory synapses
    VrevI = -80 * mV                             # Reversal potential of inhibitory synapses
    tau_decay = 5.0 * ms                         # Decay constants of AMPA-type and GABA-type conductances
    tau_rise = 1.0 * ms                          # Rise constant of AMPA- and GABA-type conductances
        # Neuron equations
        #Is it the refractoriness parameter that's screwing up the code? (no, but that is important). 
        #It's probably namespace, but that throws out more errors. 
    eqs = '''
        dV/dt = (-gea*(V-VrevE) - gi*(V-VrevI) - (V-Vl)) * (1.0/tau) + I/Cm: volt (unless refractory)
        dgea/dt = (ye-gea)*(1.0/tau_decay)        : 1
        dye/dt = -ye*(1.0/tau_rise)               : 1     
        dgi/dt = (yi-gi)*(1.0/tau_decay)          : 1
        dyi/dt = -yi*(1.0/tau_rise)               : 1     
        I : amp
        tau : second
        Cm : farad 
        ''' 
    #You cannot name a variable xi because that's what all the noise is named. 
    sensoryE = NeuronGroup(N_E, model=eqs, method='euler', namespace=locals(), threshold='V>Vt', reset='V=Vr', refractory=tau_refE) #Excitatory neurons. 
    sensoryI = NeuronGroup(N_I, model=eqs, method='euler', namespace=locals(), threshold='V>Vt', reset='V=Vr', refractory=tau_refI) #Inhibitory neurons 
    sensoryE.tau = CmE / gLeakE
    sensoryE.Cm = CmE 
    sensoryI.tau = CmI / gLeakI
    sensoryI.Cm = CmI
    sensoryE.I = 0.0
    sensoryI.I = 0.0
    sensoryE1 = sensoryE[:N_E1]
    sensoryE2 = sensoryE[N_E2:] #How to make sub-populations of neurons 
    external = PoissonGroup(N_X, rates = nu_ext)
    external1=external[:N_X1]
    external2=external[N_X2:]
    #Synapses here 
    #E1 to E1 synapses 
    C_SE1_SE1 = Synapses(sensoryE1, sensoryE1, 'w: 1', on_pre='ye+=w', namespace=locals()) #Okay, lots of wrangling to be done
    C_SE1_SE1.connect(p=0.2) #I think you need to separate these guys into different groups as the weights are different. 
    C_SE1_SE1.w='w_p*gEE/gLeakE*clip(1.0 + 0.5 * randn(), 0.0, inf)' #Fix from brian2 website. 
    C_SE1_SE1.delay='randn()*1.5*ms'
    #E2 to E2 synapes 
    C_SE2_SE2 = Synapses(sensoryE2, sensoryE2, 'w: 1', on_pre='ye+=w', namespace=locals()) #No, it's not a dimensionality error either.
    C_SE2_SE2.connect(p=0.2)  
    C_SE2_SE2.w='w_p*gEE/gLeakE*clip(1.0 + 0.5 * randn(), 0.0, inf)' 
    C_SE2_SE2.delay='randn()*1.5*ms'
    #E1 to E2 synapses 
    C_SE1_SE2 = Synapses(sensoryE1, sensoryE2, 'w: 1', on_pre='ye+=w', namespace=locals()) 
    C_SE1_SE2.connect(p=0.2)  
    C_SE1_SE2.w='w_m*gEE/gLeakE*clip(1.0 + 0.5 * randn(), 0.0, inf)' 
    C_SE1_SE2.delay='randn()*1.5*ms'
    #E2 to E1 synapses 
    C_SE2_SE1 = Synapses(sensoryE2, sensoryE1, 'w: 1', on_pre='ye+=w', namespace=locals()) 
    C_SE2_SE1.connect(p=0.2)  
    C_SE2_SE1.w='w_m*gEE/gLeakE*clip(1.0 + 0.5 * randn(), 0.0, inf)' 
    C_SE2_SE1.delay='randn()*1.5*ms'
    #E to I synapses 
    C_SE_SI=Synapses(sensoryE, sensoryI, 'w: 1', on_pre='ye+=w', namespace=locals()) 
    C_SE_SI.connect(p=0.2)
    C_SE_SI.w='gEI/gLeakI*clip(1.0 + 0.5 * randn(), 0.0, inf)' 
    C_SE_SI.delay='randn()*1.5*ms'
    #I to E synapses 
    C_SI_SE=Synapses(sensoryI, sensoryE, 'w: 1', on_pre='yi+=w', namespace=locals()) 
    C_SI_SE.connect(p=0.2)
    C_SI_SE.w='gIE/gLeakE*clip(1.0 + 0.5 * randn(), 0.0, inf)' 
    C_SI_SE.delay='randn()*0.9*ms'
    #I to I synapses 
    C_SI_SI=Synapses(sensoryI, sensoryI, 'w: 1', on_pre='yi+=w', namespace=locals()) 
    C_SI_SI.connect(p=0.2)
    C_SI_SI.w='gII/gLeakI*clip(1.0 + 0.5* randn(), 0.0, inf)' 
    C_SI_SI.delay='randn()*0.9*ms'
    #X1 to E1 synapses 
    C_SX1_SE1=Synapses(external1, sensoryE1, 'w: 1', on_pre='ye+=w', namespace=locals()) 
    C_SX1_SE1.connect(p=p_x*(1+alpha_x))
    C_SX1_SE1.w='gextE/gLeakE*clip(1.0 + 0.5 * randn(), 0.0, inf)' 
    C_SX1_SE1.delay='randn()*1.5*ms'
    #X2 to E2 synapses 
    C_SX2_SE2=Synapses(external2, sensoryE2, 'w: 1', on_pre='ye+=w', namespace=locals()) 
    C_SX2_SE2.connect(p=p_x*(1+alpha_x))
    C_SX2_SE2.w='gextE/gLeakE*clip(1.0 + 0.5 * randn(), 0.0, inf)' 
    C_SX2_SE2.delay='randn()*1.5*ms'
    #X1 to E2 synapses 
    C_SX1_SE2=Synapses(external1, sensoryE2, 'w: 1', on_pre='ye+=w', namespace=locals()) 
    C_SX1_SE2.connect(p=p_x*(1-alpha_x))
    C_SX1_SE2.w='gextE/gLeakE*clip(1.0 + 0.5 * randn(), 0.0, inf)' 
    C_SX1_SE2.delay='randn()*1.5*ms'
    #X2 to E1 synapses 
    C_SX2_SE1=Synapses(external2, sensoryE1, 'w: 1', on_pre='ye+=w', namespace=locals()) 
    C_SX2_SE1.connect(p=p_x*(1-alpha_x))
    C_SX2_SE1.w='gextE/gLeakE*clip(1.0 + 0.5 * randn(), 0.0, inf)' 
    C_SX2_SE1.delay='randn()*1.5*ms'
    #X to I synapses 
    C_SX_SI=Synapses(external, sensoryI, 'w: 1', on_pre='ye+=w', namespace=locals()) 
    C_SX_SI.connect(p=p_x)
    C_SX_SI.w='gextI/gLeakI*clip(1.0 + 0.5 * randn(), 0.0, inf)' 
    C_SX_SI.delay='randn()*1.5*ms'
    # Return the sensory circuit
    groups = {'SE': sensoryE, 'SI': sensoryI, 'SX': external}
    subgroups = {'SE1': sensoryE1, 'SE2': sensoryE2}
    connections = {'C_SX1_SE1': C_SX1_SE1, 'C_SX1_SE2': C_SX1_SE2, 'C_SX2_SE1': C_SX2_SE1, 'C_SX2_SE2': C_SX2_SE2,'C_SX_SI': C_SX_SI, 
                       'C_SE1_SE1': C_SE1_SE1, 'C_SE1_SE2': C_SE1_SE2,'C_SE2_SE1': C_SE2_SE1,'C_SE2_SE2': C_SE2_SE2, 'C_SE_SI': C_SE_SI, 'C_SI_SE': C_SI_SE, 'C_SI_SI': C_SI_SI}

    return groups, connections, subgroups

# %%
def make_integration_circuit(): #Layer 2, with some biological plausibility. 
    
    '''
    Creates the spiking network described in Wang 2002.
    
    returns:
        groups, connections, update_nmda, subgroups
        
    groups, connections, and update_nmda have to be added to the "Network" in order to run the simulation.
    subgroups is used for establishing connections between the sensory and integration circuit; do not add subgroups to the "Network"

    ''' 
    # Populations
    f_E = 0.15                                   # Fraction of stimulus-selective excitatory neurons
    N = 2000                                     # Total number of neurons
    f_inh = 0.2                                  # Fraction of inhibitory neurons
    NE = int(N * (1.0 - f_inh))                  # Number of excitatory neurons (1600)
    NI = int(N * f_inh)                          # Number of inhibitory neurons (400)
    N_D1 = int(f_E * NE)                         # Size of excitatory population D1
    N_D2 = N_D1                                  # Size of excitatory population D2
    N_DN = int((1.0 - 2.0 * f_E) * NE)           # Size of excitatory population DN

    # Connectivity - local recurrent connections
    w_p = 1.6                                    # Relative recurrent synaptic strength within populations D1 and D2
    w_m = 1.0 - f_E * (w_p - 1.0) / (1.0 - f_E) # Relative recurrent synaptic strength of connections across populations D1 and D2 and from DN to D1 and D2
    gEE_AMPA = 0.05 * nS                    # Weight of AMPA synapses between excitatory neurons
    gEE_NMDA = 0.165 * nS                        # Weight of NMDA synapses between excitatory neurons
    gEI_AMPA = 0.04 * nS                         # Weight of excitatory to inhibitory synapses (AMPA)
    gEI_NMDA = 0.13 * nS                         # Weight of excitatory to inhibitory synapses (NMDA)
    gIE_GABA = 1.3 * nS                          # Weight of inhibitory to excitatory synapses
    gII_GABA = 1.0 * nS                          # Weight of inhibitory to inhibitory synapses
    d = 0.5 * ms                                 # Transmission delay of recurrent excitatory and inhibitory connections
                                                
    # Connectivity - external connections
    gextE = 2.1 * nS                             # Weight of external input to excitatory neurons
    gextI = 1.62 * nS                            # Weight of external input to inhibitory neurons

    # Neuron model
    CmE = 0.5 * nF                               # Membrane capacitance of excitatory neurons
    CmI = 0.2 * nF                               # Membrane capacitance of inhibitory neurons
    gLeakE = 25.0 * nS                           # Leak conductance of excitatory neurons
    gLeakI = 20.0 * nS                           # Leak conductance of inhibitory neurons
    Vl = -70.0 * mV                              # Resting potential
    Vt = -50.0 * mV                              # Spiking threshold
    Vr = -55.0 * mV                              # Reset potential
    tau_refE = 2.0 * ms                          # Absolute refractory period of excitatory neurons
    tau_refI = 1.0 * ms                          # Absolute refractory period of inhibitory neurons
    
    # Synapse model
    VrevE = 0 * mV                               # Reversal potential of excitatory synapses
    VrevI = -70 * mV                             # Reversal potential of inhibitory synapses
    tau_AMPA = 2.0 * ms                          # Decay constant of AMPA-type conductances
    tau_GABA = 5.0 * ms                          # Decay constant of GABA-type conductances
    tau_NMDA_decay = 100.0 * ms                  # Decay constant of NMDA-type conductances
    tau_NMDA_rise = 2.0 * ms                     # Rise constant of NMDA-type conductances
    alpha_NMDA = 0.5 * kHz                       # Saturation constant of NMDA-type conductances
    
    # Inputs
    nu_ext_1 = 2392 * Hz             # Firing rate of external Poisson input to neurons in population D1
    nu_ext_2 = 2392 * Hz               # Firing rate of external Poisson input to neurons in population D2
    nu_ext = 2400 * Hz                 # Firing rate of external Poisson input to neurons in population Dn and I
    # External inputs
    extinputE1 = PoissonGroup(N_D1, rates = nu_ext_1) 
    extinputE2 = PoissonGroup(N_D2, rates = nu_ext_2)
    extinputE3 = PoissonGroup(N_DN, rates = nu_ext)
    extinputI = PoissonGroup(NI, rates = nu_ext)
    eqsE = '''
    dV/dt = (-gea*(V-VrevE) - gen*(V-VrevE)/(1.0+exp(-V/mV*0.062)/3.57) - gi*(V-VrevI) - (V-Vl)) / (tau): volt (unless refractory)
    dgea/dt = -gea/(tau_AMPA) : 1
    dgi/dt = -gi/(tau_GABA) : 1
    dspre/dt = -spre/(tau_NMDA_decay)+alpha_NMDA*xpre*(1-spre) : 1
    dxpre/dt= -xpre/(tau_NMDA_rise) : 1
    gen : 1
    tau : second
        '''
    eqsI = '''
        dV/dt = (-gea*(V-VrevE) - gen*(V-VrevE)/(1.0+exp(-V/mV*0.062)/3.57) - gi*(V-VrevI) - (V-Vl)) / (tau): volt (unless refractory)
        dgea/dt = -gea/(tau_AMPA) : 1
        dgi/dt = -gi/(tau_GABA) : 1
        gen : 1
        tau : second
        '''

    # Set up the integration circuit
    decisionE = NeuronGroup(NE, model=eqsE, method='euler', namespace=locals(), threshold='V>Vt', reset='V=Vr', refractory=tau_refE)
    decisionI = NeuronGroup(NI, model=eqsI, method='euler', namespace=locals(), threshold='V>Vt', reset='V=Vr', refractory=tau_refI)
    decisionE.tau = CmE / gLeakE
    decisionI.tau = CmI / gLeakI      
    decisionE1 = decisionE[:N_D1]
    decisionE2 = decisionE[N_D1:N_D1+N_D2]
    decisionE3 = decisionE[N_D1+N_D2:]
    #DE1 to DE1
    C_DE1_DE1_AMPA = Synapses(decisionE1, decisionE1, 'w: 1', on_pre='gea+=w', namespace=locals())  #Pay attention to units. 
    C_DE1_DE1_AMPA.connect() #Connect_full and connect_one_to_one are not the same thing! 
    C_DE1_DE1_AMPA.w=w_p * gEE_AMPA / gLeakE
    C_DE1_DE1_AMPA.delay=d
    #DE2 to DE2
    C_DE2_DE2_AMPA = Synapses(decisionE2, decisionE2, 'w: 1', on_pre='gea+=w', namespace=locals())   
    C_DE2_DE2_AMPA.connect()
    C_DE2_DE2_AMPA.w=w_p * gEE_AMPA / gLeakE
    C_DE2_DE2_AMPA.delay=d
    #DE1 to DE2
    C_DE1_DE2_AMPA = Synapses(decisionE1, decisionE2, 'w: 1', on_pre='gea+=w', namespace=locals())   
    C_DE1_DE2_AMPA.connect()
    C_DE1_DE2_AMPA.w=w_m * gEE_AMPA / gLeakE
    C_DE1_DE2_AMPA.delay=d
    #DE2 to DE1 
    C_DE2_DE1_AMPA = Synapses(decisionE2, decisionE1, 'w: 1', on_pre='gea+=w', namespace=locals())   
    C_DE2_DE1_AMPA.connect()
    C_DE2_DE1_AMPA.w=w_m * gEE_AMPA / gLeakE
    C_DE2_DE1_AMPA.delay=d
    #DE3 to DE1  
    C_DE3_DE1_AMPA = Synapses(decisionE3, decisionE1, 'w: 1', on_pre='gea+=w', namespace=locals())   
    C_DE3_DE1_AMPA.connect()
    C_DE3_DE1_AMPA.w=w_m * gEE_AMPA / gLeakE
    C_DE3_DE1_AMPA.delay=d
    #DE3 to DE2
    C_DE3_DE2_AMPA = Synapses(decisionE3, decisionE2, 'w: 1', on_pre='gea+=w', namespace=locals())   
    C_DE3_DE2_AMPA.connect()
    C_DE3_DE2_AMPA.w=w_m * gEE_AMPA / gLeakE
    C_DE3_DE2_AMPA.delay=d
    #DE1 to DE3
    C_DE1_DE3_AMPA = Synapses(decisionE1, decisionE3, 'w: 1', on_pre='gea+=w', namespace=locals())   
    C_DE1_DE3_AMPA.connect()
    C_DE1_DE3_AMPA.w=gEE_AMPA / gLeakE
    C_DE1_DE3_AMPA.delay=d
    #DE2 to DE3
    C_DE2_DE3_AMPA = Synapses(decisionE2, decisionE3, 'w: 1', on_pre='gea+=w', namespace=locals())   
    C_DE2_DE3_AMPA.connect()
    C_DE2_DE3_AMPA.w=gEE_AMPA / gLeakE
    C_DE2_DE3_AMPA.delay=d
    #DE3 to DE3
    C_DE3_DE3_AMPA = Synapses(decisionE3, decisionE3, 'w: 1', on_pre='gea+=w', namespace=locals())   
    C_DE3_DE3_AMPA.connect()
    C_DE3_DE3_AMPA.w= gEE_AMPA / gLeakE
    C_DE3_DE3_AMPA.delay=d
    #DE to DI
    C_DE_DI_AMPA = Synapses(decisionE, decisionI, 'w: 1', on_pre='gea+=w', namespace=locals())   
    C_DE_DI_AMPA.connect()
    #C_DE_DI_AMPA.connect(j='i')
    C_DE_DI_AMPA.w= gEI_AMPA / gLeakI
    C_DE_DI_AMPA.delay=d
    #NMDA
    selfnmda = Synapses(decisionE, decisionE, 'w : 1', on_pre='xpre+=w', namespace=locals())
    selfnmda.connect(j='i')
    selfnmda.w=1.0
    selfnmda.delay=d
    #Marcel Steinberg's fix for the NMDA synapses 
    @network_operation(when='start') #NMDA calculations
    def update_nmda():
        sE1 = sum(decisionE1.spre[:])
        sE2 = sum(decisionE2.spre[:])
        sE3 = sum(decisionE3.spre[:])
        decisionE1.gen[:] = gEE_NMDA / gLeakE * (w_p*sE1 + w_m*sE2 + w_m*sE3)
        decisionE2.gen[:] = gEE_NMDA / gLeakE * (w_m*sE1 + w_p*sE2 + w_m*sE3)
        decisionE3.gen[:] = gEE_NMDA / gLeakE * (sE1 + sE2 + sE3)
        decisionI.gen[:] = gEI_NMDA / gLeakI * (sE1 + sE2 + sE3)
    #E1_nmda = asarray(decisionE1.spre)
    #E2_nmda = asarray(decisionE2.spre)
    #E3_nmda = asarray(decisionE3.spre)         
    #E1_gen = asarray(decisionE1.gen) 
    #E2_gen = asarray(decisionE2.gen)
    #E3_gen = asarray(decisionE3.gen)
    #I_gen = asarray(decisionI.gen)
    #@network_operation(when='start') #NMDA calculations. Is this what isn't working? Yes. 
   # def update_nmda():
        #sE1 = sum(E1_nmda)
        #sE2 = sum(E2_nmda)
        #sE3 = sum(E3_nmda)
        #E1_gen[:] = gEE_NMDA / gLeakE * (w_p*sE1 + w_m*sE2 + w_m*sE3)
        #E2_gen[:] = gEE_NMDA / gLeakE * (w_m*sE1 + w_p*sE2 + w_m*sE3)
        #E3_gen[:] = gEE_NMDA / gLeakE * (sE1 + sE2 + sE3)
        #I_gen[:] = gEI_NMDA / gLeakI * (sE1 + sE2 + sE3)  
    
    #DI to DE
    C_DI_DE = Synapses(decisionI, decisionE, 'w: 1', on_pre='gi+=w', namespace=locals())  
    C_DI_DE.connect()
    C_DI_DE.w=gIE_GABA / gLeakE
    C_DI_DE.delay=d
    #DI to DI
    C_DI_DI = Synapses(decisionI, decisionI, 'w: 1', on_pre='gi+=w', namespace=locals()) 
    C_DI_DI.connect()
    C_DI_DI.w=gII_GABA / gLeakI
    C_DI_DI.delay=d
    #X1 to E1
    C_X1_E1=Synapses(extinputE1, decisionE1, 'w : 1', on_pre='gea+=w', namespace=locals())
    C_X1_E1.connect(j='i')
    C_X1_E1.w=gextE / gLeakE #BE CAREFUL! 
    C_X1_E1.delay=d
    #X2 to E2 
    C_X2_E2=Synapses(extinputE2, decisionE2, 'w : 1', on_pre='gea+=w', namespace=locals())
    C_X2_E2.connect(j='i')
    C_X2_E2.w=gextE / gLeakE
    C_X2_E2.delay=d
    #X3 to E3 
    C_X3_E3=Synapses(extinputE3, decisionE3,  'w : 1', on_pre='gea+=w', namespace=locals())
    C_X3_E3.connect(j='i')
    C_X3_E3.w=gextE / gLeakE
    C_X3_E3.delay=d
    #XI to I
    C_XI_I=Synapses(extinputI, decisionI, 'w : 1', on_pre='gea+=w', namespace=locals())
    C_XI_I.connect(j='i')
    C_XI_I.w=gextI / gLeakI
    C_XI_I.delay=d
    groups = {'DE': decisionE, 'DI': decisionI, 'DX1': extinputE1, 'DX2': extinputE2, 'DX3': extinputE3, 'DXI': extinputI}
    subgroups = {'DE1': decisionE1, 'DE2': decisionE2, 'DE3': decisionE3}  
    connections = {'selfnmda': selfnmda,
                   'extconnE1': C_X1_E1, 'extconnE2': C_X2_E2, 'extconnE3': C_X3_E3, 'extconnI': C_XI_I, 
                   'C_DE1_DE1_AMPA': C_DE1_DE1_AMPA, 'C_DE2_DE2_AMPA': C_DE2_DE2_AMPA, 'C_DE1_DE2_AMPA': C_DE1_DE2_AMPA,'C_DE2_DE1_AMPA': C_DE2_DE1_AMPA, 'C_DE3_DE1_AMPA': C_DE3_DE1_AMPA, 'C_DE3_DE2_AMPA': C_DE3_DE2_AMPA, 'C_DE1_DE3_AMPA': C_DE1_DE3_AMPA, 'C_DE3_DE3_AMPA': C_DE3_DE3_AMPA, 'C_DE2_DE3_AMPA': C_DE2_DE3_AMPA, 'C_DE_DI_AMPA': C_DE_DI_AMPA, 'C_DI_DE': C_DI_DE, 'C_DI_DI': C_DI_DI }
    return groups, connections, update_nmda, subgroups

# %%
#Simulation cell
def get_OU_stim(n, tau):
# UO process in discrete time => AR(1) process
      
    a = np.exp(-(1.0 / tau))
    i = lfilter(np.ones(1),[1.0, -a], np.sqrt(1-a*a)*randn(n))   
         
    return i

# %% [markdown]
# ### Run Simulation

# %%
connect_seed = 1284                          # seed for random number generators (set before establishing network connectivity)
stim_seed = 123                              # seed for random number generators (set before generating common part of stimulus)
init_seed = 8190                             # seed for random number generators (set before generating private part of stimulus)

# Timing 
stim_on = 500.0 * ms                         # stimulus onset
stim_off = 2500.0 * ms                       # stimulus offset   
stim_duration = stim_off - stim_on           # duration of stimulus interval
runtime = 3000.0 * ms                        # total simulation time
# Set the seed of the random number generator
np.random.seed(connect_seed) 
random.seed(connect_seed)

# Integration circuit
Dgroups, Dconnections, Dnetfunctions, Dsubgroups = make_integration_circuit() 

# get populations from the integrations circuit
decisionE = Dgroups['DE']
decisionI = Dgroups['DI']
decisionE1 = Dsubgroups['DE1']
decisionE2 = Dsubgroups['DE2']
decisionE3 = Dsubgroups['DE3']

# Sensory network  
Sgroups, Sconnections, Ssubgroups = make_sensory_circuit()

# get sensory populations
sensoryE = Sgroups['SE']
sensoryI = Sgroups['SI']
sensoryE1 = Ssubgroups['SE1']
sensoryE2 = Ssubgroups['SE2']

# Feed-forward connections from the sensory to the integration circuit

wSD = 0.0036                                 # Synaptic weight of feed-forward connections from the corresponding stimulus-encoding population 
                                                # from the sensory circuit (E1 -> D1, E2 -> D2); 
                                                # synaptic weight (0.09 nS) is given in multiples of the leak conductance of the excitatory neurons in the integration circuit  

C_SE1_DE1=Synapses(sensoryE1, decisionE1, 'w: 1', on_pre='gea+=w')
C_SE1_DE1.connect(p=0.2)
C_SE1_DE1.w=wSD 
C_SE1_DE1.delay=1.0*ms 
C_SE2_DE2=Synapses(sensoryE2, decisionE2, 'w: 1', on_pre='gea+=w')
C_SE2_DE2.connect(p=0.2)
C_SE2_DE2.w=wSD 
C_SE2_DE2.delay=1.0*ms 
# Top-down feedback connections from the integration circuit to the sensory circuit

b_FB = 0.0                                   # Feedback strength
wDS = 0.004 * b_FB                           # Synaptic weight of feedback connections from the integration circuit to the sensory circuit (D1 -> E1, D2 -> E2);
                                                # synaptic weight (0.0668 nS) is given in multiples of the leak conductance of the excitatory neurons in the sensory circuit  


C_DE1_SE1=Synapses(decisionE1, sensoryE1, 'w: 1', on_pre='ye+=w')
C_DE1_SE1.connect(p=0.2)
C_DE1_SE1.w=wDS 
C_DE1_SE1.delay=1.0*ms 
C_DE2_SE2=Synapses(decisionE2, sensoryE2, 'w: 1', on_pre='ye+=w')
C_DE2_SE2.connect(p=0.2)
C_DE2_SE2.w=wDS 
C_DE2_SE2.delay=1.0*ms 


# Stimulus parameters    
I0 = 0.08 * nA                               # Mean input current for zero-coherence stimulus 
c = 0.0                                      # Stimulus coherence (between 0 and 1) 
mu_E1 = +0.25                                # Average additional input current to E1 at highest coherence (c = 1)
mu_E2 = -0.25                                # Average additional input current to E2 at highest coherence (c = 1)    
sigma = 1.0                                  # Amplitude of temporal modulations of the stimulus
sigma_stim = 0.212 * sigma                   # S.d. of modulations of stimulus inputs
sigma_ind = 0.212 * sigma                    # S.d. of modulations in individual inputs
tau_stim = 20.0 * ms                         # Correlation time constant of Ornstein-Uhlenbeck process

# Generate stimulus
# set seed of random number generator (in order to generate a specific stimulus each time)
np.random.seed(stim_seed)    
random.seed(stim_seed)

# "common part" of the stimulus
z1 = get_OU_stim(int(stim_duration/ms), tau_stim/ms)
z1 = np.tile(z1,(len(sensoryE1),1))
z2 = get_OU_stim(int(stim_duration/ms), tau_stim/ms)
z2 = np.tile(z2,(len(sensoryE2),1))

# set seed of random number generator (in order to generate a specific stimulus each time)
np.random.seed(init_seed)    
random.seed(init_seed)

# "private part" - part of the stimulus for each neuron, different in each trial               
zk1 = get_OU_stim(int(stim_duration/ms * len(sensoryE1)), tau_stim/ms)  
zk1 = np.asarray(zk1).reshape(len(sensoryE1), int(stim_duration/ms))
zk2 = get_OU_stim(int(stim_duration/ms * len(sensoryE2)), tau_stim/ms)  
zk2 = np.asarray(zk2).reshape(len(sensoryE2), int(stim_duration/ms))

# stimulus (time series with dt = 1ms)
# most general case: different input to each neuron in each time step 
i1 = I0 * (1 + c * mu_E1 + sigma_stim * z1 + sigma_ind * zk1)     
i2 = I0 * (1 + c * mu_E2 + sigma_stim * z2 + sigma_ind * zk2)     
ii = np.zeros((len(sensoryI),int(stim_duration/ms)))     # no current input to inh population

# Stimulus-related external current input     
defaultclock.dt=0.1*ms    
@network_operation(defaultclock)
def update_input():  
    if defaultclock.t >= stim_on and defaultclock.t < stim_off: #Does this fix it?           
        sensoryE1.I = i1[:,int((defaultclock.t - stim_on) / (1 * ms))] #* amp
        sensoryE2.I = i2[:,int((defaultclock.t - stim_on) / (1 * ms))] #* amp
        sensoryI.I = ii[:,int((defaultclock.t - stim_on) / (1 * ms))] #* amp
    else:
        sensoryE1.I = 0 * nA
        sensoryE2.I = 0 * nA
        sensoryI.I = 0 * nA
# --- set seed of random number generator to a different value in each run
np_seed = int(1587.47)
np.random.seed(np_seed)
py_seed = int(4736.28) 
random.seed(py_seed)

# ---- set initial conditions (random)
#decisionE.gen = decisionE.gen * (1 + 0.2 * rand(decisionE.__len__())) #This is a different initial condition. 
#decisionI.gen = decisionI.gen * (1 + 0.2 * rand(decisionI.__len__()))
#It is not an initial condition problem. 
decisionE.gen='1+0.2*rand()' #Syntax stuff 
decisionI.gen='1+0.2*rand()'
#decisionE.V = decisionE.V + rand(decisionE.__len__()) * 2 * mV
#decisionI.V = decisionI.V + rand(decisionI.__len__()) * 2 * mV #Removes the 'all neurons spike at t=0' problem
decisionE.V='-52*mV + rand()*2*mV'
decisionI.V='-52*mV + rand()*2*mV'

# ---- set initial conditions (random)
#sensoryE.V = -50.0 * mV - 2 * mV + rand(sensoryE.__len__()) * 2 * mV
#sensoryI.V = -50.0 * mV - 2 * mV + rand(sensoryI.__len__()) * 2 * mV
sensoryE.V ='-52*mV+rand()*2*mV'
sensoryI.V ='-52*mV+rand()*2*mV'
#sensoryE.gea = 0.05 * (1 + rand(sensoryE.__len__()) * 0.2)
#sensoryI.gea = 0.05 * (1 + rand(sensoryI.__len__()) * 0.2)
sensoryE.gea='0.05*(1+0.2*rand())'
sensoryI.gea='0.05*(1+0.2*rand())'

# record spikes of excitatory neurons
S_DE1 = SpikeMonitor(decisionE1, record=True)
S_DE2 = SpikeMonitor(decisionE2, record=True)
S_SE1 = SpikeMonitor(sensoryE1, record=True)
S_SE2 = SpikeMonitor(sensoryE2, record=True)

# record instantaneous populations activity
R_DE1 = PopulationRateMonitor(decisionE1) 
R_DE2 = PopulationRateMonitor(decisionE2)
R_SE1 = PopulationRateMonitor(sensoryE1)
R_SE2 = PopulationRateMonitor(sensoryE2)

#sanity checks? 
#NMDA_DE1=StateMonitor(decisionE1, 'spre', record=True)
#NMDA_DE2=StateMonitor(decisionE2, 'spre', record=True)
# construct network       
net = Network(Dgroups.values(), Sgroups.values(), Dconnections.values(), Sconnections.values(), 
                Dnetfunctions, update_input, C_SE1_DE1, C_SE2_DE2, C_DE1_SE1, C_DE2_SE2,
                S_DE1, S_DE2, S_SE1, S_SE2, R_DE1, R_DE2, R_SE1, R_SE2)
net.run(runtime)
# Out:
# INFO:root:building '_cython_magic_492ac46125346229905e7de4e93c2d8e' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_492ac46125346229905e7de4e93c2d8e.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_492ac46125346229905e7de4e93c2d8e.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_492ac46125346229905e7de4e93c2d8e.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_492ac46125346229905e7de4e93c2d8e.cpython-39-darwin.so
# INFO:root:building '_cython_magic_debc439a84ab655fc4d3a8d54fcce8ab' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_debc439a84ab655fc4d3a8d54fcce8ab.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_debc439a84ab655fc4d3a8d54fcce8ab.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_debc439a84ab655fc4d3a8d54fcce8ab.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_debc439a84ab655fc4d3a8d54fcce8ab.cpython-39-darwin.so
# INFO:root:building '_cython_magic_f9da7578c22c7f649942a9086e726136' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f9da7578c22c7f649942a9086e726136.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f9da7578c22c7f649942a9086e726136.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f9da7578c22c7f649942a9086e726136.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f9da7578c22c7f649942a9086e726136.cpython-39-darwin.so
# INFO:root:building '_cython_magic_7dfefdd47e641dc0033888cd4a70be3d' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7dfefdd47e641dc0033888cd4a70be3d.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7dfefdd47e641dc0033888cd4a70be3d.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7dfefdd47e641dc0033888cd4a70be3d.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7dfefdd47e641dc0033888cd4a70be3d.cpython-39-darwin.so
# INFO:root:building '_cython_magic_934065238ab04f6cdae536f3ebfdd829' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_934065238ab04f6cdae536f3ebfdd829.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_934065238ab04f6cdae536f3ebfdd829.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_934065238ab04f6cdae536f3ebfdd829.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_934065238ab04f6cdae536f3ebfdd829.cpython-39-darwin.so
# INFO:root:building '_cython_magic_5bd09332b526b7be07dde40f8ceb872a' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5bd09332b526b7be07dde40f8ceb872a.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5bd09332b526b7be07dde40f8ceb872a.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5bd09332b526b7be07dde40f8ceb872a.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5bd09332b526b7be07dde40f8ceb872a.cpython-39-darwin.so
# INFO:root:building '_cython_magic_7573d3803223f8580cb47cfe383d9981' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7573d3803223f8580cb47cfe383d9981.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7573d3803223f8580cb47cfe383d9981.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7573d3803223f8580cb47cfe383d9981.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7573d3803223f8580cb47cfe383d9981.cpython-39-darwin.so
# INFO:root:building '_cython_magic_8fa6e1486679b03287b9ecc5ba9751ca' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8fa6e1486679b03287b9ecc5ba9751ca.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8fa6e1486679b03287b9ecc5ba9751ca.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8fa6e1486679b03287b9ecc5ba9751ca.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8fa6e1486679b03287b9ecc5ba9751ca.cpython-39-darwin.so
# INFO:root:building '_cython_magic_36049d6501f559035e77dbb3c69eb54b' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_36049d6501f559035e77dbb3c69eb54b.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_36049d6501f559035e77dbb3c69eb54b.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_36049d6501f559035e77dbb3c69eb54b.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_36049d6501f559035e77dbb3c69eb54b.cpython-39-darwin.so
# INFO:root:building '_cython_magic_ecedab07eaf93bce0ed5db07c05a31d0' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ecedab07eaf93bce0ed5db07c05a31d0.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ecedab07eaf93bce0ed5db07c05a31d0.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ecedab07eaf93bce0ed5db07c05a31d0.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ecedab07eaf93bce0ed5db07c05a31d0.cpython-39-darwin.so
# INFO:root:building '_cython_magic_cce3ac4c1b369565a019ef0b1aae0c4c' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_cce3ac4c1b369565a019ef0b1aae0c4c.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_cce3ac4c1b369565a019ef0b1aae0c4c.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_cce3ac4c1b369565a019ef0b1aae0c4c.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_cce3ac4c1b369565a019ef0b1aae0c4c.cpython-39-darwin.so
# INFO:root:building '_cython_magic_3b329f8e44c6246e51bd80ecbc0556f1' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_3b329f8e44c6246e51bd80ecbc0556f1.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_3b329f8e44c6246e51bd80ecbc0556f1.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_3b329f8e44c6246e51bd80ecbc0556f1.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_3b329f8e44c6246e51bd80ecbc0556f1.cpython-39-darwin.so
# INFO:root:building '_cython_magic_5a1b766aa5cd23af7025b0ddcebb7103' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5a1b766aa5cd23af7025b0ddcebb7103.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5a1b766aa5cd23af7025b0ddcebb7103.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5a1b766aa5cd23af7025b0ddcebb7103.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5a1b766aa5cd23af7025b0ddcebb7103.cpython-39-darwin.so
# INFO:root:building '_cython_magic_4b0291dccdc8eb719fdcf4137cfe4cbe' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_4b0291dccdc8eb719fdcf4137cfe4cbe.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_4b0291dccdc8eb719fdcf4137cfe4cbe.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_4b0291dccdc8eb719fdcf4137cfe4cbe.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_4b0291dccdc8eb719fdcf4137cfe4cbe.cpython-39-darwin.so
# INFO:root:building '_cython_magic_7b8e8905d272240ccbe367a8d778f1c6' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7b8e8905d272240ccbe367a8d778f1c6.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7b8e8905d272240ccbe367a8d778f1c6.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7b8e8905d272240ccbe367a8d778f1c6.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7b8e8905d272240ccbe367a8d778f1c6.cpython-39-darwin.so
# INFO:root:building '_cython_magic_7ac7d04dc6bb01840e9b552556cbfe6c' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7ac7d04dc6bb01840e9b552556cbfe6c.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7ac7d04dc6bb01840e9b552556cbfe6c.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7ac7d04dc6bb01840e9b552556cbfe6c.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_7ac7d04dc6bb01840e9b552556cbfe6c.cpython-39-darwin.so
# INFO:root:building '_cython_magic_8fa3e991653e5e743d4a6ee054a416e0' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8fa3e991653e5e743d4a6ee054a416e0.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8fa3e991653e5e743d4a6ee054a416e0.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8fa3e991653e5e743d4a6ee054a416e0.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8fa3e991653e5e743d4a6ee054a416e0.cpython-39-darwin.so
# INFO:root:building '_cython_magic_f3ce7edbadcc24f5090420cc962d5a80' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f3ce7edbadcc24f5090420cc962d5a80.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f3ce7edbadcc24f5090420cc962d5a80.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f3ce7edbadcc24f5090420cc962d5a80.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_f3ce7edbadcc24f5090420cc962d5a80.cpython-39-darwin.so
# INFO:root:building '_cython_magic_36dc1ea893dfa6931d8869b12d718172' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_36dc1ea893dfa6931d8869b12d718172.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_36dc1ea893dfa6931d8869b12d718172.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_36dc1ea893dfa6931d8869b12d718172.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_36dc1ea893dfa6931d8869b12d718172.cpython-39-darwin.so
# INFO:root:building '_cython_magic_11a4065776be70637f8dd9c61d3dbb39' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_11a4065776be70637f8dd9c61d3dbb39.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_11a4065776be70637f8dd9c61d3dbb39.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_11a4065776be70637f8dd9c61d3dbb39.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_11a4065776be70637f8dd9c61d3dbb39.cpython-39-darwin.so
# INFO:root:building '_cython_magic_af11e112d857ab7608ed2cf9d984927a' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_af11e112d857ab7608ed2cf9d984927a.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_af11e112d857ab7608ed2cf9d984927a.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_af11e112d857ab7608ed2cf9d984927a.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_af11e112d857ab7608ed2cf9d984927a.cpython-39-darwin.so
# INFO:root:building '_cython_magic_665fc96a69bdea198c72c10a3aca1ed9' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_665fc96a69bdea198c72c10a3aca1ed9.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_665fc96a69bdea198c72c10a3aca1ed9.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_665fc96a69bdea198c72c10a3aca1ed9.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_665fc96a69bdea198c72c10a3aca1ed9.cpython-39-darwin.so
# INFO:root:building '_cython_magic_5d5106380fd22b8b0520a51406ad32f1' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5d5106380fd22b8b0520a51406ad32f1.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5d5106380fd22b8b0520a51406ad32f1.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5d5106380fd22b8b0520a51406ad32f1.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5d5106380fd22b8b0520a51406ad32f1.cpython-39-darwin.so
# INFO:root:building '_cython_magic_9a460e57efbad037df55c4564833cfe1' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_9a460e57efbad037df55c4564833cfe1.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_9a460e57efbad037df55c4564833cfe1.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_9a460e57efbad037df55c4564833cfe1.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_9a460e57efbad037df55c4564833cfe1.cpython-39-darwin.so
# INFO:root:building '_cython_magic_78e4d9473127d10d2e3339038cfe1037' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_78e4d9473127d10d2e3339038cfe1037.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_78e4d9473127d10d2e3339038cfe1037.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_78e4d9473127d10d2e3339038cfe1037.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_78e4d9473127d10d2e3339038cfe1037.cpython-39-darwin.so
# INFO:root:building '_cython_magic_508781e40061ee71cb57c6640811aa20' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_508781e40061ee71cb57c6640811aa20.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_508781e40061ee71cb57c6640811aa20.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_508781e40061ee71cb57c6640811aa20.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_508781e40061ee71cb57c6640811aa20.cpython-39-darwin.so
# INFO:root:building '_cython_magic_a67428fb1f1650b830396e9b90d1c239' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_a67428fb1f1650b830396e9b90d1c239.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_a67428fb1f1650b830396e9b90d1c239.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# ...
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5e1d8255b7aeb3753c9943f4ebbb1c1a.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_5e1d8255b7aeb3753c9943f4ebbb1c1a.cpython-39-darwin.so
# INFO:root:building '_cython_magic_1f3eb5bc3ecf0334f3a311e9ba1391fb' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_1f3eb5bc3ecf0334f3a311e9ba1391fb.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_1f3eb5bc3ecf0334f3a311e9ba1391fb.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_1f3eb5bc3ecf0334f3a311e9ba1391fb.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_1f3eb5bc3ecf0334f3a311e9ba1391fb.cpython-39-darwin.so
# INFO:root:building '_cython_magic_bf90636a269ba60ac1290cdf04e8fed3' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_bf90636a269ba60ac1290cdf04e8fed3.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_bf90636a269ba60ac1290cdf04e8fed3.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_bf90636a269ba60ac1290cdf04e8fed3.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_bf90636a269ba60ac1290cdf04e8fed3.cpython-39-darwin.so
# INFO:root:building '_cython_magic_94df9ed312ab490793152f6c62dfba3f' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_94df9ed312ab490793152f6c62dfba3f.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_94df9ed312ab490793152f6c62dfba3f.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_94df9ed312ab490793152f6c62dfba3f.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_94df9ed312ab490793152f6c62dfba3f.cpython-39-darwin.so
# INFO:root:building '_cython_magic_fdf1adea14cd349eb2acdb504c15f4e7' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_fdf1adea14cd349eb2acdb504c15f4e7.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_fdf1adea14cd349eb2acdb504c15f4e7.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_fdf1adea14cd349eb2acdb504c15f4e7.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_fdf1adea14cd349eb2acdb504c15f4e7.cpython-39-darwin.so
# INFO:root:building '_cython_magic_8129efa72ef789efe18fc41c817d9ece' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8129efa72ef789efe18fc41c817d9ece.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8129efa72ef789efe18fc41c817d9ece.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8129efa72ef789efe18fc41c817d9ece.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_8129efa72ef789efe18fc41c817d9ece.cpython-39-darwin.so
# INFO:root:building '_cython_magic_ac71558533bd99b50c48b189a370804c' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ac71558533bd99b50c48b189a370804c.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ac71558533bd99b50c48b189a370804c.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ac71558533bd99b50c48b189a370804c.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_ac71558533bd99b50c48b189a370804c.cpython-39-darwin.so
# INFO:root:building '_cython_magic_1d65435926285f8aa0fd95c686eed74c' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_1d65435926285f8aa0fd95c686eed74c.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_1d65435926285f8aa0fd95c686eed74c.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_1d65435926285f8aa0fd95c686eed74c.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_1d65435926285f8aa0fd95c686eed74c.cpython-39-darwin.so
# INFO:root:building '_cython_magic_0f24817e45ae24d2b30e5bf31156e633' extension
# INFO:root:clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -iwithsysroot/System/Library/Frameworks/System.framework/PrivateHeaders -iwithsysroot/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/Headers -arch arm64 -arch x86_64 -Werror=implicit-function-declaration -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/numpy/core/include -I/Users/djpassey/Code/graphinference/graphinf_venv/lib/python3.9/site-packages/brian2/synapses -I/Users/djpassey/Code/graphinference/graphinf_venv/include -I/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/include/python3.9 -c /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_0f24817e45ae24d2b30e5bf31156e633.cpp -o /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_0f24817e45ae24d2b30e5bf31156e633.o -w -O3 -ffast-math -fno-finite-math-only -std=c++11
# INFO:root:clang++ -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -Wl,-headerpad,0x1000 /Users/djpassey/Library/Caches/cython/brian_extensions/Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_0f24817e45ae24d2b30e5bf31156e633.o -L/Users/djpassey/Code/graphinference/graphinf_venv/lib -Wl,-rpath,/Users/djpassey/Code/graphinference/graphinf_venv/lib -o /Users/djpassey/Library/Caches/cython/brian_extensions/_cython_magic_0f24817e45ae24d2b30e5bf31156e633.cpython-39-darwin.so

# %%
# Plots
bins=int(20*ms/defaultclock.dt)
binned_t=R_DE1.t[::bins]
fig, axs = plt.subplots(7,1, figsize=(12,24)) 
fig.add_axes(axs[0])
plot_raster(S_SE1.i, S_SE1.t,color=(1,0,0))
plt.xlim(0,runtime/ms)   
plt.ylim(0,len(sensoryE1))
axs[0].set_title('Sensory circuit')
fig.add_axes(axs[1])
plot_raster(S_SE2.i, S_SE2.t,color=(0,0,1))
plt.xlim(0,runtime/ms)   
plt.ylim(0,len(sensoryE2))
fig.add_axes(axs[2])
plot_rate(binned_t, np.reshape(R_SE1.rate, (-1, bins)).mean(axis=1), color=(1,0,0)) #Less annoying 
plot_rate(binned_t, np.reshape(R_SE2.rate, (-1, bins)).mean(axis=1), color=(0,0,1))
plt.yticks(range(0,30,5)) 
plt.xlim(0,runtime/ms)   
plt.ylim(0,20)
plt.ylabel("Rate (sp/s)")
fig.add_axes(axs[3])
plot_raster(S_DE1.i, S_DE1.t,color=(1,0,0))
plt.xlim(0,runtime/ms)   
plt.ylim(0,len(decisionE1))
axs[3].set_title('Integration circuit')
fig.add_axes(axs[4])
plot_raster(S_DE2.i, S_DE2.t,color=(0,0,1))
plt.xlim(0,runtime/ms)   
plt.ylim(0,len(decisionE2))
fig.add_axes(axs[5])
plot_rate(binned_t, np.reshape(R_DE1.rate, (-1, bins)).mean(axis=1), color=(1,0,0)) 
plot_rate(binned_t, np.reshape(R_DE2.rate, (-1, bins)).mean(axis=1), color=(0,0,1)) 
plt.yticks(range(0,50,10))
#yticks(range(0,30,5)) 
plt.xlim(0,runtime/ms)   
plt.ylim(0,50)
plt.ylabel("Rate (sp/s)")
fig.add_axes(axs[6])
t = np.linspace(0., int(runtime/second), int(runtime/ms))
plt.plot(t, np.r_[np.zeros(int(stim_on/ms)), np.mean(i1,0)/I0, np.zeros(int((runtime-stim_off)/ms))], color=(1,0,0))
plt.plot(t, np.r_[np.zeros(int(stim_on/ms)), np.mean(i2,0)/I0, np.zeros(int((runtime-stim_off)/ms))], color=(0,0,1))
plt.xticks(range(0,3))
plt.yticks(range(0,2,1))
plt.xlim(0,runtime/second)
plt.ylim(0,1.5)
plt.xlabel("Time (s)")
plt.ylabel("Stimulus")
for i in [0,1,3,4]:
    axs[i].set_yticklabels([])
for i in range(0,6):
    axs[i].set_xticklabels([])   
plt.show()
